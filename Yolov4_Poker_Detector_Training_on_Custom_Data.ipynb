# %% [markdown]
# <a href="https://colab.research.google.com/github/brightcome/Vitis-In-Depth-Tutorial/blob/master/Yolov4_Poker_Detector_Training_on_Custom_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## STEP 1 Install Darknet

# %% [markdown]
# # Tutorial: Training a Tiny Yolov3 Object Detector with poker cards detector
#
#
#
# In this tutorial we will train an object detector using the Tiny Yolo v3 model. This model will run on our DepthAI Myriad X modules.
#
# The model is pretrained on the COCO dataset. The framework used for training is Darknet.
# Will run through the following steps:
#
#
# *   Install the libraries (Darknet , etc.)
# *   Clone the github repo and replace the repo training data with your data (from google drive or from own repo - which is faster)
# *   Train the model on the new images
# *   Run inference on a few images to see what the model can detect
# *   Convert the model to OpenVINO Intermediate Representation
# *   To run the model on DepthAI modules, compile the IR obtained above to a .blob file
#
# You can make a copy of this tutorial: File-> Save a copy in Drive
#
# Note: the model training can be run with the repo images of medical masks if you choose to skip the customization part for your own images just to see how the training and the rest of the steps work

# %%
# %%capture
# !git clone https://github.com/AlexeyAB/darknet.git
# %cd darknet
import re
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !make
# !chmod +x ./darknet

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
#utility function
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# ## Clone a helper repo
# It makes training the medical mask detecting model easy.
# In order to train on your own data, this repo can be used as a blueprint.
# Changes to some files need to be made according to own data, but it is nothing complicated.

# %%
repo_url = 'https://github.com/GotG/yolotinyv3_medmask_demo'
import os
# %cd /content
repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))
# !git clone {repo_url}
# %cd {repo_dir_path}
# Out:
# /content
# Cloning into 'yolotinyv3_medmask_demo'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (363/363), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 1726 (delta 33), reused 286 (delta 18), pack-reused 1363
# Receiving objects: 100% (1726/1726), 208.92 MiB | 39.36 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Checking out files: 100% (1536/1536), done.
# /content/yolotinyv3_medmask_demo

# %% [markdown]
# ### Now go to the file explorer on the left of the colab notebook and click on content then on the yolotinyv3_medmask_demo folder.
# Here you will see a folder and a few files.
# The `obj` folder contains both images AND the associated annotations in yolo format.
#
# (to annotate own images use https://github.com/tzutalin/labelImg and save annotations in yolo format)
#
# * the 'obj.data' file contains paths for files used by Darknet and the number of classes to train the yolo model.
#
# * the 'obj.names' file has the labels of the objects to be detected. the number of objects gives the number of classes in the 'obj.data' file.
#
# * the train.txt contains the path to each image to be used in training. similarly, test.txt contains the path to each image for testing. when not many images are available for training (a few hundred), use all images for training for better model performance. for the mask model we have 40 images for testing and 638 images for training.
#
# * the yolov3-tiny.conv.15 are the COCO pretrained weights
#
# * the yolov3-tiny_obj.cfg are is the tiny yolov3 configuration file that tells Darknet the model parameters and structure
#
# So we can see that all these files need to be changed according to own data.

# %% [markdown]
# # How to use your own images
# In order to use your own annotated images, follow the steps below. If you want to train on the images already in the repo, skip this section and jump to the Train model section.

# %% [markdown]
# ## Let's start with the images and annotations. I will use my images as example.
# We copy the images on our google drive in a folder. My gdrive folder is named medmask_yolo. Then we mount the gdrive in colab and copy the images and annotations in the obj folder.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#remove the obj folder
# !rm -rf /content/yolotinyv3_medmask_demo/obj
#copy images to obj folder
#this can take a few minutes depending on dataset size. 
# !cp -rf '/content/drive/My Drive/datasets/medmask_yolo/obj' '/content/yolotinyv3_medmask_demo/obj'

# %% [markdown]
# ### The copy operation from gdrive to colab may take a while
# The fastest way to add data to colab is to create a github repo with your images and annotations and clone that repo here. Then copy the files from your cloned repo to the obj folder.
# First delete the obj folder using

# %%
# !rm -rf /content/yolotinyv3_medmask_demo/obj

# %% [markdown]
# Then copy from your cloned repo folder with images and annotations to the `obj` folder

# %%
# assuming your cloned image/annotation folder is named MyImages and it is under /content,
# the copy would be:
# !cp -rf '/content/MyImages' '/content/yolotinyv3_medmask_demo/obj'

# %% [markdown]
# ## Change the labels in obj.names to our current labels

# %%
labels_path = '/content/yolotinyv3_medmask_demo/obj.names'
#make a list of your labels
labels = ['mask','no mask']
# labels = ['good','bad']

with open(labels_path, 'w') as f:

    f.write('\n'.join(labels))

#check that the labels file is correct
# !cat /content/yolotinyv3_medmask_demo/obj.names
# Out:
# mask
# no mask

# %% [markdown]
# ## Change the number of classes in obj.data.
# The paths are relative so no change there as long as the folder/file structure/names are not changed.

# %%
import re
objdata = '/content/yolotinyv3_medmask_demo/obj.data'
with open(objdata) as f:
    s = f.read()

#the number of classes is equal to the number of labels
num_classes = len(labels)   
s = re.sub('classes = \d*','classes = ' + str(num_classes),s)

with open(objdata, 'w') as f:
  f.write(s)
# !cat /content/yolotinyv3_medmask_demo/obj.data
# Out:
# classes= 2
# train  = /content/yolotinyv3_medmask_demo/train.txt
# valid  = /content/yolotinyv3_medmask_demo/test.txt
# names = /content/yolotinyv3_medmask_demo/obj.names
# backup = backup/

# %% [markdown]
# ## Now we need to create a train.txt and test.txt file for our images from `obj` folder.
# We will use a script that splits the images based on a specified percentage
# and writes them in train.txt and test.txt files.

# %%
# %cd ../yolotinyv3_medmask_demo/
# Out:
# /content/yolotinyv3_medmask_demo

# %%
#in this case we use 6 percent as the number of images for testing.
#double clicking on the train or test text files will open the file in a new
#tab in colab and display the content.
# !python3 folder2textYolo.py 5 /content/yolotinyv3_medmask_demo/obj
# Out:
# Your image file extension is: .jpg
# Number of images: 762
# Number of images used for training 724
# Number of images used for testing 38

# %% [markdown]
# ## Last thing we need to change is the yolov3-tiny_obj.cfg file.
# There are several parameters of importance here. They control various aspects of the training process. Let's print the first few lines and have a look

# %%
# !head -n 24 /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg
# Out:
# [net]
# # Testing
# #batch=1
# #subdivisions=1
# # Training
# batch=64
# subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 4000
# policy=steps
# steps=3200,3600
# scales=.1,.1

# %% [markdown]
# ### Let's go over the parameters above:
# * The batch parameter dictates the batch size. That one generally remains at 64.
# * The subdivisions dictates how many images are loaded into memory. A smaller number translates to faster training. We will use 12. If a CUDA out of memory error is triggered, the subdivisions should be increased to i.e. 16,24,32 or some other number. (64 is max) Unless training with a resolution higher than 416, there should be no problem with 12.
# * The width and height are by default at 416. Another resolution one can try is 320, or 608.
# * The next parameter we care about is max_batches. This determines how long the training process is. Its value should be at least around 2000 for every class used. So for 3 classes, at least 6000.
# * The steps are calculated as a function of max_batches. The first value is 0.8 * max_batches and the second value 0.9 * max_batches. In this case it is 8000 * 0.8 and 8000 * 0.9.
#
# For more details about Yolo parameters have a look here:
# https://github.com/AlexeyAB/darknet#how-to-train-to-detect-your-custom-objects
# There is a lot of material here, so make sure you scroll through if you have questions. Pretty much everything is well explained.

# %% [markdown]
# ### Now that we see which parameters are of importance, let's modify them according to our dataset.

# %%
# set the number of max_batches - min 2000 per class:
max_batch=4000
# calculate the 2 steps values:
step1 = 0.8 * max_batch
step2 = 0.9 * max_batch

# we also need to adjust the number of classes and a parameter called filter size 
# that are both is inside the model structure

# num_classes = len(labels)
num_filters = (num_classes + 5) * 3


cfg_file = '/content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg'
# cfg_file = '/content/yolotinyv3_medmask_demo/yolov4-tiny.cfg'

with open(cfg_file) as f:
    s = f.read()
# (re.sub('[a-z]*@', 'ABC@', s))
s = re.sub('max_batches = \d*','max_batches = '+str(max_batch),s)
s = re.sub('steps=\d*,\d*','steps='+"{:.0f}".format(step1)+','+"{:.0f}".format(step2),s)
s = re.sub('classes=\d*','classes='+str(num_classes),s)
s = re.sub('pad=1\nfilters=\d*','pad=1\nfilters='+"{:.0f}".format(num_filters),s)
# pad=1\nfilters=\d\d
# s = re.sub('CUDNN=0','CUDNN=1',s)
# s = re.sub('OPENCV=0','OPENCV=1',s)

with open(cfg_file, 'w') as f:
  # s = re.sub('GPU=0','GPU=1',s)
  f.write(s)

# %% [markdown]
# Let's look again at the configuration

# %%
# !head -n 24 /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg
# Out:
# [net]
# # Testing
# #batch=1
# #subdivisions=1
# # Training
# batch=64
# subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 4000
# policy=steps
# steps=3200,3600
# scales=.1,.1

# %% [markdown]
# We also check if the number of classes and filters updated correctly

# %%
# !tail -n 64 /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg
# Out:
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=21
# activation=linear
#
#
#
# [yolo]
# mask = 3,4,5
# anchors = 10,14,  23,27,  37,58,  81,82,  135,169,  344,319
# classes=2
# num=6
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 8
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=21
# activation=linear
#
# [yolo]
# mask = 1,2,3
# anchors = 10,14,  23,27,  37,58,  81,82,  135,169,  344,319
# classes=2
# num=6
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1

# %% [markdown]
# # Train the model
#
# When you execute the following command, your model will start training.
#
# You will have a log line per epoch. On each iteration you will see how your training is going.
#
# In the `content/darknet/backup/` folder Darknet saves a few weights files:
# * files that end in 1000,2000 etc are weights saved every 1000 batches
# * best weights file are the weights that gave best results during training
# * final weights file contains the final weights at the end of the training

# %% [markdown]
# ## Start the model training

# %%
# %cd ../darknet/
# Out:
# /content/darknet

# %%
# !./darknet detector train /content/yolotinyv3_medmask_demo/obj.data /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg /content/yolotinyv3_medmask_demo/yolov3-tiny.conv.15 -dont_show -ext_output -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.783581), count: 9, total_loss = 0.652960
#  total_bbox = 1012558, rewritten_bbox = 0.032393 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.856619), count: 3, total_loss = 0.158645
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.737971), count: 16, total_loss = 2.410450
#  total_bbox = 1012577, rewritten_bbox = 0.032393 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.855124), count: 3, total_loss = 0.338645
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.777626), count: 15, total_loss = 2.387240
#  total_bbox = 1012595, rewritten_bbox = 0.032392 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.751895), count: 5, total_loss = 0.427572
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.770904), count: 15, total_loss = 1.620025
#  total_bbox = 1012615, rewritten_bbox = 0.032391 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.788456), count: 2, total_loss = 0.084925
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.696464), count: 10, total_loss = 1.960097
#  total_bbox = 1012627, rewritten_bbox = 0.032391 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.873695), count: 3, total_loss = 0.131778
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.784874), count: 7, total_loss = 0.692974
#  total_bbox = 1012637, rewritten_bbox = 0.032391 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.897798), count: 1, total_loss = 0.008156
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.770909), count: 16, total_loss = 1.774700
#  total_bbox = 1012654, rewritten_bbox = 0.032390 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.770982), count: 4, total_loss = 0.191274
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.815577), count: 4, total_loss = 0.327251
#  total_bbox = 1012662, rewritten_bbox = 0.032390 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812363), count: 2, total_loss = 0.067001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.838646), count: 7, total_loss = 0.725062
#  total_bbox = 1012671, rewritten_bbox = 0.032390 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827125), count: 5, total_loss = 0.547838
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.836411), count: 9, total_loss = 0.791406
#  total_bbox = 1012685, rewritten_bbox = 0.032389 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.857324), count: 5, total_loss = 0.188969
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.705806), count: 30, total_loss = 3.911505
#  total_bbox = 1012720, rewritten_bbox = 0.032388 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.885984), count: 2, total_loss = 0.092529
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.776370), count: 8, total_loss = 1.156680
#  total_bbox = 1012730, rewritten_bbox = 0.032388 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.830137), count: 1, total_loss = 0.019677
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.818314), count: 10, total_loss = 0.515628
#  total_bbox = 1012741, rewritten_bbox = 0.032387 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.835051), count: 2, total_loss = 0.125804
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.749345), count: 6, total_loss = 0.511283
#  total_bbox = 1012749, rewritten_bbox = 0.032387 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.780953), count: 1, total_loss = 0.039488
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.742205), count: 8, total_loss = 0.482547
#  total_bbox = 1012758, rewritten_bbox = 0.032387 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.787988), count: 6, total_loss = 0.324198
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.829227), count: 8, total_loss = 0.556920
#  total_bbox = 1012772, rewritten_bbox = 0.032386 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3908: 0.727072, 0.798358 avg loss, 0.000010 rate, 0.860767 seconds, 250112 images, 0.064989 hours left
# Loaded: 0.121808 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.764299), count: 3, total_loss = 0.425204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.753677), count: 13, total_loss = 1.662082
#  total_bbox = 1012788, rewritten_bbox = 0.032386 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.778824), count: 1, total_loss = 0.037109
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.762078), count: 9, total_loss = 1.283022
#  total_bbox = 1012798, rewritten_bbox = 0.032386 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.811421), count: 4, total_loss = 0.485014
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.755303), count: 27, total_loss = 3.988028
#  total_bbox = 1012829, rewritten_bbox = 0.032385 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.831096), count: 4, total_loss = 0.085718
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.727042), count: 10, total_loss = 1.484602
#  total_bbox = 1012843, rewritten_bbox = 0.032384 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.829143), count: 4, total_loss = 0.227566
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.787012), count: 7, total_loss = 0.812237
#  total_bbox = 1012854, rewritten_bbox = 0.032384 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.757428), count: 3, total_loss = 0.477224
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.757547), count: 22, total_loss = 2.508063
#  total_bbox = 1012879, rewritten_bbox = 0.032383 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.785417), count: 2, total_loss = 0.180140
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.786389), count: 30, total_loss = 5.038021
#  total_bbox = 1012911, rewritten_bbox = 0.032382 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.837113), count: 5, total_loss = 0.283945
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.753689), count: 5, total_loss = 0.365786
#  total_bbox = 1012921, rewritten_bbox = 0.032382 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844546), count: 2, total_loss = 0.064372
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.747477), count: 40, total_loss = 4.301360
#  total_bbox = 1012963, rewritten_bbox = 0.032380 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.816195), count: 4, total_loss = 0.185205
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.804681), count: 7, total_loss = 0.299144
#  total_bbox = 1012974, rewritten_bbox = 0.032380 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.893560), count: 3, total_loss = 0.161282
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.824593), count: 7, total_loss = 0.378605
#  total_bbox = 1012984, rewritten_bbox = 0.032380 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.678299), count: 1, total_loss = 0.117681
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.789471), count: 6, total_loss = 0.307954
#  total_bbox = 1012991, rewritten_bbox = 0.032379 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.838912), count: 1, total_loss = 0.035726
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.702261), count: 36, total_loss = 4.909581
#  total_bbox = 1013028, rewritten_bbox = 0.032378 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849045), count: 3, total_loss = 0.048289
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.788969), count: 13, total_loss = 1.225895
#  total_bbox = 1013044, rewritten_bbox = 0.032378 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.795663), count: 4, total_loss = 0.423843
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761518), count: 17, total_loss = 1.973932
#  total_bbox = 1013065, rewritten_bbox = 0.032377 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.835501), count: 4, total_loss = 0.333469
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790491), count: 9, total_loss = 0.772647
#  total_bbox = 1013078, rewritten_bbox = 0.032377 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3909: 1.090086, 0.827530 avg loss, 0.000010 rate, 0.843232 seconds, 250176 images, 0.064596 hours left
# Loaded: 0.076289 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801295), count: 2, total_loss = 0.515782
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.754765), count: 8, total_loss = 0.972891
#  total_bbox = 1013088, rewritten_bbox = 0.032376 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, total_loss = 0.000340
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.765216), count: 19, total_loss = 1.449208
#  total_bbox = 1013107, rewritten_bbox = 0.032376 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.847400), count: 3, total_loss = 0.056222
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801956), count: 12, total_loss = 1.099405
#  total_bbox = 1013122, rewritten_bbox = 0.032375 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, total_loss = 0.000014
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.738444), count: 21, total_loss = 2.141574
#  total_bbox = 1013143, rewritten_bbox = 0.032375 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.810720), count: 1, total_loss = 0.098355
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.721760), count: 14, total_loss = 1.613740
#  total_bbox = 1013158, rewritten_bbox = 0.032374 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.709011), count: 3, total_loss = 0.224216
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.740767), count: 23, total_loss = 2.725757
#  total_bbox = 1013184, rewritten_bbox = 0.032373 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.769679), count: 2, total_loss = 0.202071
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.774210), count: 6, total_loss = 1.072318
#  total_bbox = 1013192, rewritten_bbox = 0.032373 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.917239), count: 1, total_loss = 0.192568
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761101), count: 11, total_loss = 0.876615
#  total_bbox = 1013204, rewritten_bbox = 0.032373 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.890149), count: 2, total_loss = 0.016124
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.750995), count: 6, total_loss = 0.432703
#  total_bbox = 1013212, rewritten_bbox = 0.032372 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.772784), count: 5, total_loss = 0.188456
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.771689), count: 13, total_loss = 1.143082
#  total_bbox = 1013230, rewritten_bbox = 0.032372 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.829794), count: 2, total_loss = 0.372586
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.758227), count: 16, total_loss = 0.707078
#  total_bbox = 1013248, rewritten_bbox = 0.032371 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.796564), count: 2, total_loss = 0.424765
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.723092), count: 12, total_loss = 2.095951
#  total_bbox = 1013262, rewritten_bbox = 0.032371 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.795269), count: 3, total_loss = 0.152431
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.805675), count: 11, total_loss = 1.138776
#  total_bbox = 1013276, rewritten_bbox = 0.032370 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.749283), count: 4, total_loss = 0.702219
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.466741), count: 1, total_loss = 0.786346
#  total_bbox = 1013281, rewritten_bbox = 0.032370 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.826328), count: 5, total_loss = 0.194888
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.838480), count: 8, total_loss = 0.483243
#  total_bbox = 1013294, rewritten_bbox = 0.032370 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.850040), count: 3, total_loss = 0.041436
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.760139), count: 18, total_loss = 2.976563
#  total_bbox = 1013315, rewritten_bbox = 0.032369 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3910: 0.784304, 0.823208 avg loss, 0.000010 rate, 0.813389 seconds, 250240 images, 0.064194 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.201204 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.743328), count: 1, total_loss = 0.149798
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.737834), count: 16, total_loss = 2.329029
#  total_bbox = 1013332, rewritten_bbox = 0.032368 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.771235), count: 3, total_loss = 0.667684
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.804489), count: 19, total_loss = 1.468429
#  total_bbox = 1013354, rewritten_bbox = 0.032368 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.782838), count: 2, total_loss = 0.068502
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.779580), count: 14, total_loss = 1.224318
#  total_bbox = 1013370, rewritten_bbox = 0.032367 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.809166), count: 3, total_loss = 0.274777
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.768243), count: 22, total_loss = 2.025226
#  total_bbox = 1013395, rewritten_bbox = 0.032366 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.784168), count: 2, total_loss = 0.111847
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.759602), count: 20, total_loss = 2.801956
#  total_bbox = 1013417, rewritten_bbox = 0.032366 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.515986), count: 1, total_loss = 0.392913
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.808120), count: 13, total_loss = 0.915031
#  total_bbox = 1013431, rewritten_bbox = 0.032365 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812438), count: 3, total_loss = 0.243749
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.770320), count: 14, total_loss = 1.683425
#  total_bbox = 1013448, rewritten_bbox = 0.032365 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812931), count: 9, total_loss = 0.904727
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.810189), count: 7, total_loss = 1.037534
#  total_bbox = 1013464, rewritten_bbox = 0.032364 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827791), count: 8, total_loss = 0.656348
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.824173), count: 6, total_loss = 0.314686
#  total_bbox = 1013478, rewritten_bbox = 0.032364 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.837899), count: 4, total_loss = 0.110820
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.757808), count: 11, total_loss = 1.295238
#  total_bbox = 1013493, rewritten_bbox = 0.032363 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.795287), count: 2, total_loss = 0.224592
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.769617), count: 11, total_loss = 1.052389
#  total_bbox = 1013506, rewritten_bbox = 0.032363 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.739512), count: 4, total_loss = 1.012446
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.730170), count: 9, total_loss = 1.432921
#  total_bbox = 1013519, rewritten_bbox = 0.032362 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822501), count: 9, total_loss = 0.491172
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.804450), count: 8, total_loss = 0.757306
#  total_bbox = 1013536, rewritten_bbox = 0.032362 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.863124), count: 11, total_loss = 0.842427
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.742315), count: 21, total_loss = 3.166374
#  total_bbox = 1013568, rewritten_bbox = 0.032361 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.760863), count: 6, total_loss = 0.685520
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761206), count: 19, total_loss = 2.780267
#  total_bbox = 1013593, rewritten_bbox = 0.032360 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.798742), count: 5, total_loss = 1.026742
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.772439), count: 37, total_loss = 3.170747
#  total_bbox = 1013635, rewritten_bbox = 0.032359 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3911: 1.103717, 0.851259 avg loss, 0.000010 rate, 1.499650 seconds, 250304 images, 0.063775 hours left
# Loaded: 0.000036 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.772439), count: 11, total_loss = 1.710178
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.785045), count: 16, total_loss = 1.996964
#  total_bbox = 1013662, rewritten_bbox = 0.032358 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.758788), count: 5, total_loss = 0.640099
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761903), count: 8, total_loss = 1.244408
#  total_bbox = 1013675, rewritten_bbox = 0.032358 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.788409), count: 8, total_loss = 1.754932
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761250), count: 4, total_loss = 0.905313
#  total_bbox = 1013687, rewritten_bbox = 0.032357 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.836609), count: 6, total_loss = 0.316547
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.779894), count: 12, total_loss = 1.185573
#  total_bbox = 1013705, rewritten_bbox = 0.032357 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.841642), count: 3, total_loss = 0.555781
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.740589), count: 10, total_loss = 1.122427
#  total_bbox = 1013718, rewritten_bbox = 0.032356 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.785147), count: 6, total_loss = 1.298646
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.733095), count: 2, total_loss = 0.272726
#  total_bbox = 1013726, rewritten_bbox = 0.032356 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823092), count: 3, total_loss = 0.283775
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.765955), count: 20, total_loss = 3.426494
#  total_bbox = 1013749, rewritten_bbox = 0.032355 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802318), count: 3, total_loss = 0.486140
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.734766), count: 8, total_loss = 1.173460
#  total_bbox = 1013760, rewritten_bbox = 0.032355 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.789546), count: 4, total_loss = 0.577054
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.773167), count: 11, total_loss = 2.104594
#  total_bbox = 1013775, rewritten_bbox = 0.032354 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.744011), count: 4, total_loss = 1.112543
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.787298), count: 8, total_loss = 0.318181
#  total_bbox = 1013787, rewritten_bbox = 0.032354 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.791974), count: 7, total_loss = 0.530415
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.771502), count: 17, total_loss = 2.015936
#  total_bbox = 1013811, rewritten_bbox = 0.032353 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.831684), count: 8, total_loss = 0.474369
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.827933), count: 21, total_loss = 1.584613
#  total_bbox = 1013840, rewritten_bbox = 0.032352 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.832752), count: 8, total_loss = 0.558094
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.755350), count: 20, total_loss = 4.085551
#  total_bbox = 1013868, rewritten_bbox = 0.032351 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.770871), count: 3, total_loss = 0.354093
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.756501), count: 3, total_loss = 0.346918
#  total_bbox = 1013874, rewritten_bbox = 0.032351 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802300), count: 4, total_loss = 0.151769
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.777302), count: 11, total_loss = 1.286612
#  total_bbox = 1013889, rewritten_bbox = 0.032351 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.720278), count: 5, total_loss = 0.803130
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.738395), count: 2, total_loss = 0.125370
#  total_bbox = 1013896, rewritten_bbox = 0.032350 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3912: 1.087584, 0.874891 avg loss, 0.000010 rate, 1.508477 seconds, 250368 images, 0.063558 hours left
# Loaded: 0.000049 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823644), count: 5, total_loss = 0.184991
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.796359), count: 8, total_loss = 0.809614
#  total_bbox = 1013909, rewritten_bbox = 0.032350 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844539), count: 3, total_loss = 0.048104
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.719922), count: 11, total_loss = 2.403853
#  total_bbox = 1013923, rewritten_bbox = 0.032350 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827171), count: 5, total_loss = 0.157196
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.805093), count: 38, total_loss = 3.053799
#  total_bbox = 1013966, rewritten_bbox = 0.032348 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802893), count: 9, total_loss = 0.990918
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.792264), count: 9, total_loss = 0.675701
#  total_bbox = 1013984, rewritten_bbox = 0.032348 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.803433), count: 4, total_loss = 0.366541
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.771164), count: 5, total_loss = 0.903723
#  total_bbox = 1013993, rewritten_bbox = 0.032347 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.691410), count: 5, total_loss = 1.206133
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.806797), count: 25, total_loss = 2.555326
#  total_bbox = 1014023, rewritten_bbox = 0.032346 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.817371), count: 8, total_loss = 0.379693
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.852708), count: 14, total_loss = 0.937373
#  total_bbox = 1014045, rewritten_bbox = 0.032346 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.815363), count: 9, total_loss = 1.056113
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790046), count: 26, total_loss = 4.350087
#  total_bbox = 1014080, rewritten_bbox = 0.032345 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812422), count: 5, total_loss = 0.534676
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.722691), count: 1, total_loss = 0.062050
#  total_bbox = 1014086, rewritten_bbox = 0.032344 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.663183), count: 1, total_loss = 0.125447
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790844), count: 22, total_loss = 2.280450
#  total_bbox = 1014109, rewritten_bbox = 0.032344 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, total_loss = 0.103017
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.769650), count: 37, total_loss = 4.159584
#  total_bbox = 1014146, rewritten_bbox = 0.032342 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823787), count: 6, total_loss = 0.441629
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.711103), count: 9, total_loss = 1.887187
#  total_bbox = 1014161, rewritten_bbox = 0.032342 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.846694), count: 6, total_loss = 0.123495
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801056), count: 24, total_loss = 2.246647
#  total_bbox = 1014191, rewritten_bbox = 0.032341 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.775743), count: 6, total_loss = 0.324728
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.791495), count: 20, total_loss = 2.601995
#  total_bbox = 1014217, rewritten_bbox = 0.032340 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.664723), count: 1, total_loss = 0.302031
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.766658), count: 12, total_loss = 0.887383
#  total_bbox = 1014230, rewritten_bbox = 0.032340 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.833826), count: 12, total_loss = 0.531452
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.823370), count: 10, total_loss = 0.492196
#  total_bbox = 1014252, rewritten_bbox = 0.032339 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3913: 1.161973, 0.903599 avg loss, 0.000010 rate, 1.478633 seconds, 250432 images, 0.063291 hours left
# Loaded: 0.000036 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844274), count: 4, total_loss = 0.112520
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, total_loss = 0.001058
#  total_bbox = 1014256, rewritten_bbox = 0.032339 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.842783), count: 4, total_loss = 0.357657
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.782267), count: 21, total_loss = 1.413616
#  total_bbox = 1014281, rewritten_bbox = 0.032338 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.881482), count: 1, total_loss = 0.019937
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.817111), count: 8, total_loss = 0.676605
#  total_bbox = 1014290, rewritten_bbox = 0.032338 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.862833), count: 1, total_loss = 0.011443
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.822462), count: 17, total_loss = 1.156797
#  total_bbox = 1014308, rewritten_bbox = 0.032337 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.828742), count: 1, total_loss = 0.212665
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.734060), count: 16, total_loss = 2.224519
#  total_bbox = 1014325, rewritten_bbox = 0.032337 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.754828), count: 2, total_loss = 0.075037
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.766005), count: 28, total_loss = 3.390001
#  total_bbox = 1014355, rewritten_bbox = 0.032336 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.740150), count: 3, total_loss = 0.395524
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.764631), count: 5, total_loss = 0.455369
#  total_bbox = 1014363, rewritten_bbox = 0.032336 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.833648), count: 7, total_loss = 0.390231
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.783613), count: 9, total_loss = 1.057108
#  total_bbox = 1014379, rewritten_bbox = 0.032335 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.715643), count: 6, total_loss = 1.816308
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.764215), count: 7, total_loss = 1.302745
#  total_bbox = 1014392, rewritten_bbox = 0.032335 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822682), count: 1, total_loss = 0.099142
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.785949), count: 21, total_loss = 1.626640
#  total_bbox = 1014414, rewritten_bbox = 0.032334 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.725991), count: 4, total_loss = 1.038677
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.789365), count: 2, total_loss = 0.876025
#  total_bbox = 1014420, rewritten_bbox = 0.032334 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.795238), count: 2, total_loss = 0.353374
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.774976), count: 20, total_loss = 1.833322
#  total_bbox = 1014442, rewritten_bbox = 0.032333 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.821302), count: 6, total_loss = 0.923419
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.784741), count: 12, total_loss = 0.995782
#  total_bbox = 1014460, rewritten_bbox = 0.032332 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822162), count: 3, total_loss = 0.656249
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.682920), count: 15, total_loss = 3.125141
#  total_bbox = 1014478, rewritten_bbox = 0.032332 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.723577), count: 7, total_loss = 1.032501
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.812540), count: 20, total_loss = 1.890644
#  total_bbox = 1014505, rewritten_bbox = 0.032331 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.907863), count: 3, total_loss = 0.054974
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.787395), count: 17, total_loss = 1.883422
#  total_bbox = 1014525, rewritten_bbox = 0.032330 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3914: 0.983077, 0.911547 avg loss, 0.000010 rate, 1.454218 seconds, 250496 images, 0.063015 hours left
# Loaded: 0.000040 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.804326), count: 7, total_loss = 0.484784
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.759057), count: 25, total_loss = 3.160970
#  total_bbox = 1014557, rewritten_bbox = 0.032329 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.775858), count: 4, total_loss = 0.213356
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.766337), count: 28, total_loss = 4.284649
#  total_bbox = 1014589, rewritten_bbox = 0.032328 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.768501), count: 1, total_loss = 0.268841
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.785979), count: 11, total_loss = 1.251706
#  total_bbox = 1014601, rewritten_bbox = 0.032328 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.705752), count: 2, total_loss = 0.500020
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.830742), count: 4, total_loss = 0.409080
#  total_bbox = 1014607, rewritten_bbox = 0.032328 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.775113), count: 4, total_loss = 0.295979
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.746904), count: 23, total_loss = 2.778884
#  total_bbox = 1014634, rewritten_bbox = 0.032327 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.776877), count: 1, total_loss = 0.076093
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.678724), count: 17, total_loss = 3.239357
#  total_bbox = 1014652, rewritten_bbox = 0.032326 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.687495), count: 1, total_loss = 0.178584
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761396), count: 20, total_loss = 3.908504
#  total_bbox = 1014673, rewritten_bbox = 0.032326 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.778006), count: 4, total_loss = 0.439200
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.811095), count: 7, total_loss = 0.552244
#  total_bbox = 1014684, rewritten_bbox = 0.032325 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802268), count: 7, total_loss = 0.985547
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.786957), count: 3, total_loss = 0.388610
#  total_bbox = 1014694, rewritten_bbox = 0.032325 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.836099), count: 3, total_loss = 0.380760
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.811909), count: 8, total_loss = 0.541593
#  total_bbox = 1014705, rewritten_bbox = 0.032325 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.848422), count: 4, total_loss = 0.178847
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801594), count: 16, total_loss = 1.628762
#  total_bbox = 1014725, rewritten_bbox = 0.032324 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.854247), count: 3, total_loss = 0.103565
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.776703), count: 19, total_loss = 1.161633
#  total_bbox = 1014747, rewritten_bbox = 0.032323 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.834195), count: 4, total_loss = 0.259351
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761339), count: 22, total_loss = 2.419442
#  total_bbox = 1014773, rewritten_bbox = 0.032322 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801957), count: 4, total_loss = 0.552803
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.852778), count: 5, total_loss = 0.496324
#  total_bbox = 1014781, rewritten_bbox = 0.032322 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.813189), count: 11, total_loss = 0.782259
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.754251), count: 22, total_loss = 3.634666
#  total_bbox = 1014814, rewritten_bbox = 0.032321 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812486), count: 4, total_loss = 0.326038
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.838101), count: 10, total_loss = 0.292538
#  total_bbox = 1014828, rewritten_bbox = 0.032321 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3915: 1.130468, 0.933439 avg loss, 0.000010 rate, 1.533708 seconds, 250560 images, 0.062732 hours left
# Loaded: 0.000037 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.816996), count: 4, total_loss = 0.242147
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.722572), count: 21, total_loss = 2.257250
#  total_bbox = 1014853, rewritten_bbox = 0.032320 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.803839), count: 8, total_loss = 1.538481
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.815735), count: 3, total_loss = 0.230740
#  total_bbox = 1014864, rewritten_bbox = 0.032320 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.808584), count: 7, total_loss = 0.409137
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.771726), count: 14, total_loss = 2.291053
#  total_bbox = 1014885, rewritten_bbox = 0.032319 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.804540), count: 7, total_loss = 0.685502
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.725912), count: 4, total_loss = 1.225957
#  total_bbox = 1014896, rewritten_bbox = 0.032319 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.813486), count: 11, total_loss = 0.844503
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.818135), count: 13, total_loss = 1.235871
#  total_bbox = 1014920, rewritten_bbox = 0.032318 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.871299), count: 6, total_loss = 0.085842
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.772095), count: 21, total_loss = 2.330730
#  total_bbox = 1014947, rewritten_bbox = 0.032317 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.830259), count: 4, total_loss = 0.345720
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.712050), count: 19, total_loss = 3.561459
#  total_bbox = 1014970, rewritten_bbox = 0.032316 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.831593), count: 6, total_loss = 0.217095
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.814042), count: 15, total_loss = 1.200763
#  total_bbox = 1014991, rewritten_bbox = 0.032316 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.766472), count: 2, total_loss = 0.308029
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.657944), count: 13, total_loss = 2.709049
#  total_bbox = 1015006, rewritten_bbox = 0.032315 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.892655), count: 8, total_loss = 0.094492
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.815026), count: 18, total_loss = 1.229420
#  total_bbox = 1015032, rewritten_bbox = 0.032314 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.755291), count: 4, total_loss = 0.495978
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, total_loss = 0.001174
#  total_bbox = 1015036, rewritten_bbox = 0.032314 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.817937), count: 7, total_loss = 0.706595
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.805381), count: 9, total_loss = 0.887261
#  total_bbox = 1015052, rewritten_bbox = 0.032314 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.760283), count: 7, total_loss = 0.938478
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790923), count: 16, total_loss = 1.837694
#  total_bbox = 1015074, rewritten_bbox = 0.032313 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.829619), count: 7, total_loss = 0.562332
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.737751), count: 15, total_loss = 1.783683
#  total_bbox = 1015096, rewritten_bbox = 0.032312 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.760363), count: 4, total_loss = 0.952229
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, total_loss = 0.000110
#  total_bbox = 1015100, rewritten_bbox = 0.032312 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.826080), count: 3, total_loss = 0.401102
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.803830), count: 2, total_loss = 0.129667
#  total_bbox = 1015105, rewritten_bbox = 0.032312 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3916: 0.991861, 0.939281 avg loss, 0.000010 rate, 1.500069 seconds, 250624 images, 0.062467 hours left
# Loaded: 0.000037 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.773342), count: 3, total_loss = 0.467353
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.744496), count: 7, total_loss = 0.814139
#  total_bbox = 1015115, rewritten_bbox = 0.032312 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.727857), count: 4, total_loss = 0.816046
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.699192), count: 7, total_loss = 1.755043
#  total_bbox = 1015126, rewritten_bbox = 0.032311 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.757151), count: 5, total_loss = 0.671802
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.719656), count: 9, total_loss = 3.436457
#  total_bbox = 1015140, rewritten_bbox = 0.032311 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.806680), count: 8, total_loss = 0.429758
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.769410), count: 19, total_loss = 2.181227
#  total_bbox = 1015167, rewritten_bbox = 0.032310 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.647033), count: 4, total_loss = 1.002514
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.743398), count: 4, total_loss = 0.661044
#  total_bbox = 1015175, rewritten_bbox = 0.032310 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849382), count: 9, total_loss = 0.744614
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.783939), count: 22, total_loss = 3.172554
#  total_bbox = 1015206, rewritten_bbox = 0.032309 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.776691), count: 6, total_loss = 0.318203
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.760920), count: 16, total_loss = 1.821611
#  total_bbox = 1015228, rewritten_bbox = 0.032308 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.675372), count: 5, total_loss = 0.600316
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.829986), count: 1, total_loss = 0.128678
#  total_bbox = 1015234, rewritten_bbox = 0.032308 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.812080), count: 5, total_loss = 0.182559
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.825155), count: 9, total_loss = 1.436155
#  total_bbox = 1039695, rewritten_bbox = 0.031932 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.762976), count: 5, total_loss = 0.525350
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.752107), count: 4, total_loss = 0.614085
#  total_bbox = 1039704, rewritten_bbox = 0.031932 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.932721), count: 1, total_loss = 0.156591
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.802243), count: 10, total_loss = 0.511638
#  total_bbox = 1039715, rewritten_bbox = 0.031932 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801331), count: 5, total_loss = 0.175176
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.763590), count: 15, total_loss = 2.221509
#  total_bbox = 1039735, rewritten_bbox = 0.031931 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.816437), count: 5, total_loss = 0.831282
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.746303), count: 2, total_loss = 0.425638
#  total_bbox = 1039742, rewritten_bbox = 0.031931 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.790977), count: 5, total_loss = 0.825016
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.874547), count: 3, total_loss = 0.175202
#  total_bbox = 1039750, rewritten_bbox = 0.031931 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802180), count: 6, total_loss = 0.395327
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.802242), count: 24, total_loss = 2.054158
#  total_bbox = 1039780, rewritten_bbox = 0.031930 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.776308), count: 3, total_loss = 0.423127
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.777437), count: 14, total_loss = 0.788433
#  total_bbox = 1039797, rewritten_bbox = 0.031929 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.814617), count: 1, total_loss = 0.069648
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790058), count: 8, total_loss = 1.080154
#  total_bbox = 1039806, rewritten_bbox = 0.031929 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.818531), count: 11, total_loss = 0.963067
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.813427), count: 17, total_loss = 1.607929
#  total_bbox = 1039834, rewritten_bbox = 0.031928 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.810996), count: 6, total_loss = 0.341987
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.819074), count: 14, total_loss = 1.008643
#  total_bbox = 1039854, rewritten_bbox = 0.031928 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.764668), count: 6, total_loss = 0.853218
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.844973), count: 9, total_loss = 0.570609
#  total_bbox = 1039869, rewritten_bbox = 0.031927 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.811919), count: 3, total_loss = 0.275315
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.824513), count: 10, total_loss = 0.772418
#  total_bbox = 1039882, rewritten_bbox = 0.031927 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.754796), count: 4, total_loss = 1.000901
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, total_loss = 0.000296
#  total_bbox = 1039886, rewritten_bbox = 0.031927 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, total_loss = 0.000386
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.734935), count: 17, total_loss = 1.688360
#  total_bbox = 1039903, rewritten_bbox = 0.031926 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3998: 0.801451, 1.085846 avg loss, 0.000010 rate, 1.510431 seconds, 255872 images, 0.036998 hours left
# Loaded: 0.000037 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.775094), count: 3, total_loss = 0.320520
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.730413), count: 20, total_loss = 3.064284
#  total_bbox = 1039926, rewritten_bbox = 0.031925 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.754794), count: 7, total_loss = 0.831533
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.758416), count: 21, total_loss = 2.448749
#  total_bbox = 1039954, rewritten_bbox = 0.031924 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.795017), count: 11, total_loss = 1.665965
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.767141), count: 13, total_loss = 3.394159
#  total_bbox = 1039978, rewritten_bbox = 0.031924 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.786584), count: 4, total_loss = 0.492654
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.731995), count: 5, total_loss = 1.037472
#  total_bbox = 1039987, rewritten_bbox = 0.031923 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.782964), count: 5, total_loss = 0.381794
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.697021), count: 7, total_loss = 2.053549
#  total_bbox = 1039999, rewritten_bbox = 0.032019 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.799748), count: 2, total_loss = 0.204426
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.825763), count: 11, total_loss = 0.703441
#  total_bbox = 1040012, rewritten_bbox = 0.032019 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.798659), count: 13, total_loss = 0.861859
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.866343), count: 10, total_loss = 1.124359
#  total_bbox = 1040035, rewritten_bbox = 0.032018 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844101), count: 4, total_loss = 0.219865
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.832243), count: 13, total_loss = 0.759200
#  total_bbox = 1040052, rewritten_bbox = 0.032018 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.670401), count: 6, total_loss = 2.091796
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, total_loss = 0.000495
#  total_bbox = 1040058, rewritten_bbox = 0.032017 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844373), count: 8, total_loss = 0.257884
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.855678), count: 9, total_loss = 0.590954
#  total_bbox = 1040075, rewritten_bbox = 0.032017 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.808008), count: 7, total_loss = 0.527662
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.787176), count: 9, total_loss = 0.653200
#  total_bbox = 1040091, rewritten_bbox = 0.032016 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.873269), count: 2, total_loss = 0.026756
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.849232), count: 12, total_loss = 0.672186
#  total_bbox = 1040105, rewritten_bbox = 0.032016 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.761491), count: 3, total_loss = 0.537150
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.641232), count: 5, total_loss = 1.153107
#  total_bbox = 1040113, rewritten_bbox = 0.032016 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.840747), count: 3, total_loss = 0.063972
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.742016), count: 10, total_loss = 1.499176
#  total_bbox = 1040126, rewritten_bbox = 0.032015 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.767650), count: 5, total_loss = 0.502203
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.798745), count: 14, total_loss = 1.303894
#  total_bbox = 1040145, rewritten_bbox = 0.032015 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.803000), count: 4, total_loss = 0.375397
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801352), count: 26, total_loss = 1.765696
#  total_bbox = 1040175, rewritten_bbox = 0.032014 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  3999: 0.987042, 1.075966 avg loss, 0.000010 rate, 1.450286 seconds, 255936 images, 0.036637 hours left
# Loaded: 0.000048 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.798193), count: 4, total_loss = 0.298807
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.794148), count: 32, total_loss = 3.024811
#  total_bbox = 1040211, rewritten_bbox = 0.032013 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.773438), count: 20, total_loss = 1.909208
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.764045), count: 34, total_loss = 5.342922
#  total_bbox = 1040265, rewritten_bbox = 0.032011 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.748354), count: 5, total_loss = 1.093217
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.834319), count: 5, total_loss = 0.447915
#  total_bbox = 1040275, rewritten_bbox = 0.032011 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.877018), count: 5, total_loss = 0.520412
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.773556), count: 2, total_loss = 0.265214
#  total_bbox = 1040282, rewritten_bbox = 0.032011 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.793939), count: 8, total_loss = 0.797152
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.795363), count: 20, total_loss = 1.891775
#  total_bbox = 1040310, rewritten_bbox = 0.032010 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.778243), count: 6, total_loss = 0.826709
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.777131), count: 20, total_loss = 2.236514
#  total_bbox = 1040336, rewritten_bbox = 0.032009 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.780838), count: 7, total_loss = 1.050113
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.732431), count: 10, total_loss = 2.463115
#  total_bbox = 1040353, rewritten_bbox = 0.032008 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.888344), count: 6, total_loss = 0.064855
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.797701), count: 17, total_loss = 1.808389
#  total_bbox = 1040376, rewritten_bbox = 0.032008 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.811425), count: 8, total_loss = 0.856196
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.766702), count: 10, total_loss = 1.466078
#  total_bbox = 1040394, rewritten_bbox = 0.032007 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.720842), count: 9, total_loss = 1.419427
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.707377), count: 3, total_loss = 1.344798
#  total_bbox = 1040406, rewritten_bbox = 0.032007 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.772785), count: 2, total_loss = 0.167010
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.794749), count: 9, total_loss = 0.706654
#  total_bbox = 1040417, rewritten_bbox = 0.032006 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823620), count: 1, total_loss = 0.024935
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.790189), count: 27, total_loss = 1.949703
#  total_bbox = 1040445, rewritten_bbox = 0.032006 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.794129), count: 10, total_loss = 0.543877
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.770999), count: 19, total_loss = 3.452481
#  total_bbox = 1040474, rewritten_bbox = 0.032005 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.815632), count: 6, total_loss = 0.732100
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.710467), count: 6, total_loss = 1.601709
#  total_bbox = 1040486, rewritten_bbox = 0.032004 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.781727), count: 4, total_loss = 0.751033
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.628187), count: 3, total_loss = 0.598020
#  total_bbox = 1040493, rewritten_bbox = 0.032004 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.779812), count: 7, total_loss = 0.593458
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.808304), count: 6, total_loss = 0.734834
#  total_bbox = 1040506, rewritten_bbox = 0.032004 %
#
#  (next mAP calculation at 4000 iterations)
#  Last accuracy mAP@0.5 = 54.97 %, best = 55.62 %
#  4000: 1.280733, 1.096443 avg loss, 0.000010 rate, 1.498899 seconds, 256000 images, 0.036274 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#  Detection layer: 16 - type = 28
#  Detection layer: 23 - type = 28
# 40
#  detections_count = 614, unique_truth_count = 300
# class_id = 0, name = mask, ap = 66.87%   	 (TP = 154, FP = 13)
# class_id = 1, name = no mask, ap = 39.05%   	 (TP = 14, FP = 3)
#
#  for conf_thresh = 0.25, precision = 0.91, recall = 0.56, F1-score = 0.69
#  for conf_thresh = 0.25, TP = 168, FP = 16, FN = 132, average IoU = 69.37 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.529600, or 52.96 %
# Total Detection Time: 1 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.529600
# Saving weights to backup//yolov3-tiny_obj_4000.weights
# Saving weights to backup//yolov3-tiny_obj_last.weights
# Saving weights to backup//yolov3-tiny_obj_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %% [markdown]
# ## Check the model performance
# The metrics run on the test images so they may not be fully representative, only indicative

# %%
# !./darknet detector map /content/yolotinyv3_medmask_demo/obj.data /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg "/content/darknet/backup/yolov3-tiny_obj_best.weights" -points 0
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     21       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  21 0.004 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     21       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  21 0.007 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.449
# avg_outputs = 325057
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/darknet/backup/yolov3-tiny_obj_best.weights...
#  seen 64, trained: 224 K-images (3 Kilo-batches_64)
# Done! Loaded 24 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 16 - type = 27
#  Detection layer: 23 - type = 27
# 40
#  detections_count = 496, unique_truth_count = 194
# class_id = 0, name = mask, ap = 78.49%   	 (TP = 122, FP = 17)
# class_id = 1, name = no mask, ap = 52.86%   	 (TP = 19, FP = 8)
#
#  for conf_thresh = 0.25, precision = 0.85, recall = 0.73, F1-score = 0.78
#  for conf_thresh = 0.25, TP = 141, FP = 25, FN = 53, average IoU = 65.50 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.656755, or 65.68 %
# Total Detection Time: 2 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %% [markdown]
# ## Run detection on an image. I choose one of the test images from test.txt

# %%
# !./darknet detector test /content/yolotinyv3_medmask_demo/obj.data  /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg  "/content/darknet/backup/yolov3-tiny_obj_best.weights" /content/yolotinyv3_medmask_demo/obj/0633.jpg -ext_output
imShow('predictions.jpg')
# Out:
# /bin/bash: ./darknet: No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4881ff69ca9> in <module>()
#       1 get_ipython().system('./darknet detector test /content/yolotinyv3_medmask_demo/obj.data  /content/yolotinyv3_medmask_demo/yolov3-tiny_obj.cfg  "/content/darknet/backup/yolov3-tiny_obj_best.weights" /content/yolotinyv3_medmask_demo/obj/0633.jpg -ext_output')
# ----> 2 imShow('predictions.jpg')
#
# NameError: name 'imShow' is not defined

# %% [markdown]
# ## Copy best weights to google drive

# %%
# !cp /content/darknet/backup/yolov3-tiny_obj_best.weights  '/content/drive/My Drive/'

# %% [markdown]
# # Convert model so it can be used on DepthAI
# This requires three steps:
# 1. Convert model to Tensorflow frozen model
# 2. Convert Tf model to OpenVINO IR files .xml and .bin
# 3. Compile a blob from the IR files. The blob can be used for inference on DepthAI modules.

# %% [markdown]
# ### Convert YOLO model to Tensorflow frozen model

# %%
# %cd ..
# Out:
# /content

# %%
#clone a repo that helps with the conversion
# !git clone https://github.com/mystic123/tensorflow-yolo-v3.git
# Out:
# Cloning into 'tensorflow-yolo-v3'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 219 (delta 1), reused 2 (delta 0), pack-reused 213
# Receiving objects: 100% (219/219), 59.90 KiB | 989.00 KiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# %cd tensorflow-yolo-v3/
# !git checkout ed60b90
# Out:
# /content/tensorflow-yolo-v3
# Note: checking out 'ed60b90'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at ed60b90 Merge pull request #53 from alexzhangxx/small_change

# %% [markdown]
# Convert the best yolo weights to Tensorflow frozen model.
# The name and location of the frozen model is
#
#
#  `/content/tensorflow-yolo-v3/frozen_darknet_yolov3_model.pb`

# %%
# !python3 convert_weights_pb.py --class_names /content/yolotinyv3_medmask_demo/obj.names --data_format NHWC --weights_file /content/darknet/backup/yolov3-tiny_obj_best.weights --tiny
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From convert_weights_pb.py:52: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:38: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 15:22:57.495909 139849999845248 module_wrapper.py:139] From convert_weights_pb.py:38: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:40: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0731 15:22:57.504635 139849999845248 module_wrapper.py:139] From convert_weights_pb.py:40: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0731 15:22:57.508399 139849999845248 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/tensorflow-yolo-v3/yolo_v3.py:180: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0731 15:22:57.866824 139849999845248 module_wrapper.py:139] From /content/tensorflow-yolo-v3/yolo_v3.py:180: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:42: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0731 15:22:57.928081 139849999845248 module_wrapper.py:139] From convert_weights_pb.py:42: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /content/tensorflow-yolo-v3/utils.py:93: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0731 15:22:57.941006 139849999845248 module_wrapper.py:139] From /content/tensorflow-yolo-v3/utils.py:93: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:47: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0731 15:22:58.219857 139849999845248 module_wrapper.py:139] From convert_weights_pb.py:47: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-07-31 15:22:58.221375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-31 15:22:58.234393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.234937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-07-31 15:22:58.235282: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-31 15:22:58.236729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-31 15:22:58.355674: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-31 15:22:58.356144: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-31 15:22:58.623282: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-31 15:22:58.649174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-31 15:22:58.652132: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-31 15:22:58.652275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.652885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.653390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-07-31 15:22:58.667010: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-07-31 15:22:58.667503: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2204f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-31 15:22:58.667533: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-31 15:22:58.749880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.751033: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2205100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-31 15:22:58.751195: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-07-31 15:22:58.751449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.752100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-07-31 15:22:58.752187: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-31 15:22:58.752216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-31 15:22:58.752238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-31 15:22:58.752260: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-31 15:22:58.752278: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-31 15:22:58.752296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-31 15:22:58.752315: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-31 15:22:58.752394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.753004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.753558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-07-31 15:22:58.759902: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-31 15:22:58.761173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-31 15:22:58.761202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-07-31 15:22:58.761212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-07-31 15:22:58.764878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.765548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-31 15:22:58.766090: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-07-31 15:22:58.766134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /content/tensorflow-yolo-v3/utils.py:52: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 15:23:05.152611 139849999845248 module_wrapper.py:139] From /content/tensorflow-yolo-v3/utils.py:52: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /content/tensorflow-yolo-v3/utils.py:53: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0731 15:23:05.228411 139849999845248 deprecation.py:323] From /content/tensorflow-yolo-v3/utils.py:53: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0731 15:23:05.228721 139849999845248 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 59 variables.
# I0731 15:23:05.272704 139849999845248 graph_util_impl.py:334] Froze 59 variables.
# INFO:tensorflow:Converted 59 variables to const ops.
# I0731 15:23:05.310094 139849999845248 graph_util_impl.py:394] Converted 59 variables to const ops.
# WARNING:tensorflow:From /content/tensorflow-yolo-v3/utils.py:56: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0731 15:23:05.312613 139849999845248 module_wrapper.py:139] From /content/tensorflow-yolo-v3/utils.py:56: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# 299 ops written to frozen_darknet_yolov3_model.pb.

# %% [markdown]
# ###Install OpenVINO 20.01

# %%
# %cd ..
# Out:
# /content

# %%
# %%time
# %%capture
## install tools. Open Vino takes some time to download: 10-15 min sometimes.
# !sudo apt-get install -y pciutils cpio
# !sudo apt autoremove
## downnload installation files
# !wget http://registrationcenter-download.intel.com/akdlm/irc_nas/16345/l_openvino_toolkit_p_2020.1.023.tgz
path = "l_openvino_toolkit_p_2020.1.023.tgz"
# path = "/content/software/Intel OpenVINO 2019 R3.1/l_openvino_toolkit_p_2019.3.376.tgz"
## install openvino
# !tar xf "{path}"
# %cd l_openvino_toolkit_p_2020.1.023/
# !./install_openvino_dependencies.sh && \
    sed -i 's/decline/accept/g' silent.cfg && \
    ./install.sh --silent silent.cfg
# Out:
# CPU times: user 248 ms, sys: 206 ms, total: 453 ms
# Wall time: 2min 14s

# %% [markdown]
# ###Convert frozen TF model to openvino 20.01 IRv10
# --input model is the path to the frozen model from above
#
# --output_dir is where we want to save the converted IR files: .xml .bin and .mapping. we save it in TinyIR in the /content/yolotinyv3_medmask_demo directory

# %%
# %cd ..
# Out:
# /content

# %%
tiny_yolo_json = '/content/yolotinyv3_medmask_demo/yolo_v3_tiny.json'

with open(tiny_yolo_json) as f:
    s = f.read()
s = re.sub('"classes": \d*','"classes": ' + str(len(labels)),s)
with open(tiny_yolo_json, 'w') as f:
  f.write(s)
#Check that the number of classes is correct (same as the number of your training labels)|
# !cat /content/yolotinyv3_medmask_demo/yolo_v3_tiny.json
# Out:
# [
#   {
#     "id": "TFYOLOV3",
#     "match_kind": "general",
#     "custom_attributes": {
#       "classes": 2,
#       "anchors": [10, 14, 23, 27, 37, 58, 81, 82, 135, 169, 344, 319],
#       "coords": 4,
#       "num": 6,
#       "masks": [[3, 4, 5], [1, 2, 3]],
#       "entry_points": ["detector/yolo-v3-tiny/Reshape", "detector/yolo-v3-tiny/Reshape_4"]
#     }
#   }
# ]

# %%
# !source /opt/intel/openvino/bin/setupvars.sh && \
    python /opt/intel/openvino/deployment_tools/model_optimizer/mo.py \
--input_model /content/tensorflow-yolo-v3/frozen_darknet_yolov3_model.pb \
--tensorflow_use_custom_operations_config /content/yolotinyv3_medmask_demo/yolo_v3_tiny.json \
--batch 1 \
--data_type FP16 \
--reverse_input_channel \
--output_dir /content/yolotinyv3_medmask_demo/TinyIR
# Out:
# [setupvars.sh] OpenVINO environment initialized
# [ WARNING ]  Use of deprecated cli option --tensorflow_use_custom_operations_config detected. Option use in the following releases will be fatal. Please use --transformations_config cli option instead
# Model Optimizer arguments:
# Common parameters:
# 	- Path to the Input Model: 	/content/tensorflow-yolo-v3/frozen_darknet_yolov3_model.pb
# 	- Path for generated IR: 	/content/yolotinyv3_medmask_demo/TinyIR
# 	- IR output name: 	frozen_darknet_yolov3_model
# 	- Log level: 	ERROR
# 	- Batch: 	1
# 	- Input layers: 	Not specified, inherited from the model
# 	- Output layers: 	Not specified, inherited from the model
# 	- Input shapes: 	Not specified, inherited from the model
# 	- Mean values: 	Not specified
# 	- Scale values: 	Not specified
# 	- Scale factor: 	Not specified
# 	- Precision of IR: 	FP16
# 	- Enable fusing: 	True
# 	- Enable grouped convolutions fusing: 	True
# 	- Move mean values to preprocess section: 	False
# 	- Reverse input channels: 	True
# TensorFlow specific parameters:
# 	- Input model in text protobuf format: 	False
# 	- Path to model dump for TensorBoard: 	None
# 	- List of shared libraries with TensorFlow custom layers implementation: 	None
# 	- Update the configuration file with input/output node names: 	None
# 	- Use configuration file used to generate the model with Object Detection API: 	None
# 	- Operations to offload: 	None
# 	- Patterns to offload: 	None
# 	- Use the config file: 	/content/yolotinyv3_medmask_demo/yolo_v3_tiny.json
# Model Optimizer version: 	2020.1.0-61-gd349c3ba4a
#
# [ SUCCESS ] Generated IR version 10 model.
# [ SUCCESS ] XML file: /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.xml
# [ SUCCESS ] BIN file: /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.bin
# [ SUCCESS ] Total execution time: 5.78 seconds.
# [ SUCCESS ] Memory consumed: 531 MB.

# %% [markdown]
# ## Now we compile the IR model to a .blob for use on DepthAI modules/platform

# %% [markdown]
# ### We save the blob in the IR directory from above, corresponding to --output_dir parameter above.
# The blob filename and location will be
#
#  `/content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.blob`

# %%
#CHOOSE the directory where you would like to save the blob.
# I use the same --output_dir as above for the IR conversion
blob_dir = "/content/yolotinyv3_medmask_demo/TinyIR/"

#Copy the path of your .xml and .bin files. For that, you can look at the IR
#conversion output cell, select and copy from:
#[SUCCESS] XML file and bin file paths.
#Or you can choose to compile other .xml .bin files from a different location
#
binfile = "/content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.bin"
xmlfile = "/content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.xml"

import requests

#For openvino 20.01 use this link to compile the blob
url = "http://69.164.214.171:8080"


#open vino 20.02 link:
# url = "69.164.214.171:8081"

payload = {'compiler_params': '-ip U8 -VPU_MYRIAD_PLATFORM VPU_MYRIAD_2480 -VPU_NUMBER_OF_SHAVES 4 -VPU_NUMBER_OF_CMX_SLICES 4'}
files = [
  ('definition', open(xmlfile,'rb')),
  ('weights', open(binfile,'rb'))
]
# headers = {
#   'Content-Type': 'application/json'
# }
response = requests.request("POST", url, data = payload, files = files)
blobnameraw = response.headers.get('Content-Disposition')
blobname = blobnameraw[blobnameraw.find('='):][1:]
with open(blob_dir + blobname, 'wb') as f:
  f.write(response.content)

# %% [markdown]
# ##Now you can download your .blob file and run it on the DepthAI module/platform
# To download locally, use the file explorer on the left to locate the file in the blob_dir folder used above, then right click download. Colab takes a few seconds to prepare the file, then the download prompt will appear.

# %%
#name the archive as you see fit
# !tar cvf medmask_tinyv3.tar /content/yolotinyv3_medmask_demo/TinyIR
# Out:
# tar: Removing leading `/' from member names
# /content/yolotinyv3_medmask_demo/TinyIR/
# /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.blob
# /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.mapping
# /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.xml
# /content/yolotinyv3_medmask_demo/TinyIR/frozen_darknet_yolov3_model.bin

# %% [markdown]
# ## To run the .blob in DepthAI, follow step 5 here:
#  https://docs.luxonis.com/tutorials/object_det_mnssv2_training/

# %% [markdown]
# ##[Optional] to convert the blob locally, download the IR files .bin and .xml and follow these instructions: https://github.com/luxonis/depthai#conversion-of-existing-trained-models-into-intel-movidius-binary-format

# %%
#Compress the folder with the Tensorflow model and OpenVINO IR_V10 folder and download it locally.
#These are in content/models/research/fine_tuned_model, so we compress the fine_tuned_model folder.
# !tar cvf fine_tuned_model.tar fine_tuned_model

# %%
#download the compressed IRv10 folder locally
#or can use file navigator on the left to move it to your gdrive
from google.colab import files
files.download("fine_tuned_model.tar.gz")
